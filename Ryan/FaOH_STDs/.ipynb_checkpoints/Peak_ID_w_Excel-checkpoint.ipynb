# %%
import pandas as pd
import numpy as np
#from pandas import ExcelWriter
#from pandas import ExcelFile
#from scipy import stats
import matplotlib.pyplot as plt
import math
import xlwt
import openpyxl

# %%
wb = openpyxl.load_workbook('GCData_for_Ryan_w_FaOH_STD_Data.xlsx')
sheet1 = ''
sheet1 = wb['John_Code']
sheet2 = ''
sheet2 = wb['Peak_ID (2)']

# %%
df = pd.read_excel('GCData_for_Ryan_w_FaOH_STD_Data', sheet_name = 'John_Code')


#Preparing list of strings called Vial_names where each element is the name of a sample

Vial_names = []
Standard_names = ['FAOH-10', 'FAOH-100', 'FAOH-2000', 'FAOH-50', 'FAOH-500']
Sample_names = ['CM24', 'CM32', 'I287A', 'rec', 'trc', 'vhb']

for x in Sample_names:
    vial1 = x + '-1'
    Vial_names.append(vial1)
    vial2 = x + '-2'
    Vial_names.append(vial2)
    vial3 = x + '-3'
    Vial_names.append(vial3)
    
for x in Standard_names:
    Vial_names.append(x)

# %%
df
# Out:
#      1g_oddfames Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0          Peak#     R.Time     I.Time     F.Time       Area     Height
# 1              1      1.361      1.288      1.382       2083       1122
# 2              2      1.413      1.382      1.489       5507       1704
# 3              3      1.521      1.489      2.287  695024823  120059358
# 4              4      2.359      2.287      3.113    1582248     469064
# 5              5      2.981      2.917      3.099      17895       5644
# 6              6      3.926      3.832      4.228    1808591     623172
# 7              7      5.166      5.101      5.292       5776       1938
# 8              8      6.797      6.641      6.944    2066882     570294
# 9              9      7.409      7.332        7.5       1433        301
# 10            10      7.562        7.5      7.658      10289       3370
# 11            11       7.77      7.705      7.901       1109        275
# 12            12      8.974      8.806       9.04       2171        397
# 13            13     10.855     10.738     11.037    2369550     759086
# 14            14     11.233     11.182      11.28       3614       1902
# 15            15     11.532     11.387     11.648       4497       1390
# 16            16     11.942     11.905      11.98       1536        777
# 17            17      12.03      11.98     12.063       2193        566
# 18            18     12.203     12.063     12.264       9762       1416
# 19            19     12.317     12.264     12.432       5757       1128
# 20            20     12.451     12.432      12.53       1381        297
# 21            21     12.859     12.745     12.955    2552762    1064512
# 22            22     13.009     12.955     13.053       1235        365
# 23            23     13.232     13.202     13.291       1155        645
# 24            24     13.536     13.487     13.576       2248       1460
# 25            25     13.709     13.585     13.753       3151       1850
# 26            26     14.187     13.982     14.266    2048413     998337
# 27            27     14.384     14.266      14.43      10345       3409
# 28            28     14.554      14.43     14.579       9560       1198
# 29            29     14.714     14.579     14.756      12694       1985
# ...          ...        ...        ...        ...        ...        ...
# 2028          85     17.683     17.663     17.715       1996        769
# 2029          86     17.764     17.715     17.822       9988       3926
# 2030          87      17.92     17.887     17.962       1632        753
# 2031          88     18.062     17.962     18.167      81778      12265
# 2032          89     18.186     18.167     18.312      35539       4841
# 2033          90     18.387     18.312     18.433      33392       5771
# 2034          91     18.486     18.433     18.583      54382      10892
# 2035          92     18.609     18.583     18.681      16404       2975
# 2036          93     18.779     18.681      18.83      24098       3073
# 2037          94     18.971      18.83     19.035      36065       4421
# 2038          95      19.11     19.035     19.157      17254       2610
# 2039          96     19.189     19.157     19.213       7346       2229
# 2036        NaN        NaN        NaN        NaN         NaN         NaN
# 2037        NaN        NaN        NaN        NaN         NaN         NaN
# 2038        NaN        NaN        NaN        NaN         NaN         NaN
# 2039        NaN        NaN        NaN        NaN         NaN         NaN
# 2040        NaN        NaN        NaN        NaN         NaN         NaN
# 2041        NaN        NaN        NaN        NaN         NaN         NaN
# 2042        NaN        NaN        NaN        NaN         NaN         NaN
# 2043        NaN        NaN        NaN        NaN         NaN         NaN
# 2044        NaN        NaN        NaN        NaN         NaN         NaN
# 2045        NaN        NaN        NaN        NaN         NaN         NaN
# 2046        NaN        NaN        NaN        NaN         NaN         NaN
# 2047        NaN        NaN        NaN        NaN         NaN         NaN
# 2048        NaN        NaN        NaN        NaN         NaN         NaN
# 2049        NaN        NaN        NaN        NaN         NaN         NaN
# 2050        NaN        NaN        NaN        NaN         NaN         NaN
# 2051        NaN        NaN        NaN        NaN         NaN         NaN
# 2052        NaN        NaN        NaN        NaN         NaN         NaN
# 2053        NaN        NaN        NaN        NaN         NaN         NaN
# 2054        NaN        NaN        NaN        NaN         NaN         NaN
# 2055        NaN        NaN        NaN        NaN         NaN         NaN
# 2056        NaN        NaN        NaN        NaN         NaN         NaN
# 2057        NaN        NaN        NaN        NaN         NaN         NaN
#
#      Unnamed: 12 Unnamed: 13
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# 4            NaN         NaN
# 5            NaN         NaN
# 6            NaN         NaN
# 7            NaN         NaN
# 8            NaN         NaN
# 9            NaN         NaN
# 10           NaN         NaN
# 11           NaN         NaN
# 12           NaN         NaN
# 13           NaN         NaN
# 14           NaN         NaN
# 15           NaN         NaN
# 16           NaN         NaN
# 17           NaN         NaN
# 18           NaN         NaN
# 19           NaN         NaN
# 20           NaN         NaN
# 21           NaN         NaN
# 22           NaN         NaN
# 23           NaN         NaN
# 24           NaN         NaN
# 25           NaN         NaN
# 26           NaN         NaN
# 27           NaN         NaN
# 28           NaN         NaN
# 29           NaN         NaN
# ...          ...         ...
# 2028         NaN         NaN
# 2029         NaN         NaN
# 2030         NaN         NaN
# 2031         NaN         NaN
# 2032         NaN         NaN
# 2033         NaN         NaN
# 2034         NaN         NaN
# 2035         NaN         NaN
# 2036         NaN         NaN
# 2037         NaN         NaN
# 2038         NaN         NaN
# 2039         NaN         NaN
# 2040         NaN         NaN
# 2041         NaN         NaN
# 2042         NaN         NaN
# 2043         NaN         NaN
# 2044         NaN         NaN
# 2045         NaN         NaN
# 2046         NaN         NaN
# 2047         NaN         NaN
# 2048         NaN         NaN
# 2049         NaN         NaN
# 2050         NaN         NaN
# 2051         NaN         NaN
# 2052         NaN         NaN
# 2053         NaN         NaN
# 2054         NaN         NaN
# 2055         NaN         NaN
# 2056         NaN         NaN
# 2057         NaN         NaN
#
# [2058 rows x 14 columns]

# %%
# FAME Retention Times (minutes on DB-Fatwax column)

C7 = 2.35
C8 = 3.06
C9 = 3.92
C10 = 5.29
C11 = 6.79
C12 = 9.22
C13 = 10.86
C14 = 12.05
C15 = 12.86
C16 = 13.62
C17 = 14.18

# Create a dictionary which can be updated by changing values above. The dictionary will be called in peak identification (next block)

RT_dict = {'C7': C7, 'C8': C8, 'C9': C9, 'C10': C10, 'C11': C11, 'C12': C12, 'C13': C13, 'C14': C14, 'C15': C15, 'C16': C16, 'C17': C17}

# Create list of analytes to make it easy to call dictionary in future
analytes = ['C7', 'C8', 'C9', 'C10', 'C11', 'C12', 'C13', 'C14', 'C15', 'C16', 'C17']

# %%
# This block goes through the dataframe from the John_Code sheet and picks out sample names and relevant peaks.

num_rows = len(df)
row_name = list(range(0, num_rows))

for i in row_name:                
    if i < num_rows+1: 
        # picks out each row in dataframe and truncates - would be more elegant to not have to use dataframe but whatever
        row_calling = df.loc[i,:]
        vals = row_calling.values.tolist()
        vals = vals[0:6]
        
        # picks out sample names and adds to worksheet
        for label in Vial_names:
            if vals[0] == label:
                print(vals[0])
                heading = [vals[0],vals[0],vals[0],vals[0],vals[0],vals[0]]
                print(heading)
                sheet2.append(heading)
                
        # picks out peaks
        x = type(vals[1])
        if x == float:
            for a in analytes:
                upper_tolerance = RT_dict[a] + 0.09
                lower_tolerance = RT_dict[a] - 0.09
                if vals[1] < upper_tolerance and vals[1] > lower_tolerance:
                    #print(vals[1])
                    vals.append(a)
                    #print(vals)
                    sheet2.append(vals[1:])
# Out:
# 100mg_oddfames
# ['100mg_oddfames', '100mg_oddfames', '100mg_oddfames', '100mg_oddfames', '100mg_oddfames', '100mg_oddfames']
# 25mg_oddfames
# ['25mg_oddfames', '25mg_oddfames', '25mg_oddfames', '25mg_oddfames', '25mg_oddfames', '25mg_oddfames']
# 500mg_oddfames
# ['500mg_oddfames', '500mg_oddfames', '500mg_oddfames', '500mg_oddfames', '500mg_oddfames', '500mg_oddfames']
# FAME100
# ['FAME100', 'FAME100', 'FAME100', 'FAME100', 'FAME100', 'FAME100']
# FAME1000
# ['FAME1000', 'FAME1000', 'FAME1000', 'FAME1000', 'FAME1000', 'FAME1000']
# FAME25
# ['FAME25', 'FAME25', 'FAME25', 'FAME25', 'FAME25', 'FAME25']
# FAME500
# ['FAME500', 'FAME500', 'FAME500', 'FAME500', 'FAME500', 'FAME500']
# H204A-1
# ['H204A-1', 'H204A-1', 'H204A-1', 'H204A-1', 'H204A-1', 'H204A-1']
# H204A-2
# ['H204A-2', 'H204A-2', 'H204A-2', 'H204A-2', 'H204A-2', 'H204A-2']
# H204A-3
# ['H204A-3', 'H204A-3', 'H204A-3', 'H204A-3', 'H204A-3', 'H204A-3']
# Rec-1
# ['Rec-1', 'Rec-1', 'Rec-1', 'Rec-1', 'Rec-1', 'Rec-1']
# Rec-2
# ['Rec-2', 'Rec-2', 'Rec-2', 'Rec-2', 'Rec-2', 'Rec-2']
# Rec-3
# ['Rec-3', 'Rec-3', 'Rec-3', 'Rec-3', 'Rec-3', 'Rec-3']
# Sc1-1
# ['Sc1-1', 'Sc1-1', 'Sc1-1', 'Sc1-1', 'Sc1-1', 'Sc1-1']
# Sc1-2
# ['Sc1-2', 'Sc1-2', 'Sc1-2', 'Sc1-2', 'Sc1-2', 'Sc1-2']
# Sc1-3
# ['Sc1-3', 'Sc1-3', 'Sc1-3', 'Sc1-3', 'Sc1-3', 'Sc1-3']
# WT-1
# ['WT-1', 'WT-1', 'WT-1', 'WT-1', 'WT-1', 'WT-1']
# WT-2
# ['WT-2', 'WT-2', 'WT-2', 'WT-2', 'WT-2', 'WT-2']
# WT-3
# ['WT-3', 'WT-3', 'WT-3', 'WT-3', 'WT-3', 'WT-3']

# %%
wb.save('GCData_for_Ryan_w_FaOH_STD_Data.xlsx')
