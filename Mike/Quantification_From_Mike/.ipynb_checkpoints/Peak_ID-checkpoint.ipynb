# %%
import pandas as pd
import numpy as np
from pandas import ExcelWriter
from pandas import ExcelFile
from scipy import stats
import statistics
import matplotlib.pyplot as plt
import math

# %%
df = pd.read_excel('GCData.xlsx', sheet_name = 'Sheet1')

# %%
df
# Out:
#            PeakNo  R.Time  I.Time  F.Time       Area     Height Unnamed: 6  \
# 0     1g_oddfames     NaN     NaN     NaN        NaN        NaN        NaN
# 1           Peak#  R.Time  I.Time  F.Time       Area     Height        NaN
# 2               1   1.361   1.288   1.382       2083       1122        NaN
# 3               2   1.413   1.382   1.489       5507       1704        NaN
# 4               3   1.521   1.489   2.287  695024823  120059358        NaN
# ...           ...     ...     ...     ...        ...        ...        ...
# 2051          110  21.594  21.518  21.681       8717       1938        NaN
# 2052          111  21.733  21.681  21.793       1517        312        NaN
# 2053          112  21.845  21.793  21.943       1014        211        NaN
# 2054          113  22.071  21.947  22.255       3670        473        NaN
# 2055          114  22.453  22.395  22.479       1289        473        NaN
#
#      Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# ...

# %%
Sample_names = ['1g_oddfames', '100mg_oddfames','poop']

data_block = []

row_name = list(range(0,2056))

for i in row_name:
    if i < 100:
        row_calling = df.loc[i,:]
        vals = row_calling.values.tolist()
        vals = vals[0:6]
        for label in Sample_names:
            if vals[0] == label:
                data_block.append(vals)
                    
        #val = df.loc[df.PeakNo == row_name]
        #short_list = val.iloc[0:0,0:5]
        #print(short_list)

# %%
# Out:
# ['1g_oddfames', nan, nan, nan, nan, nan]
